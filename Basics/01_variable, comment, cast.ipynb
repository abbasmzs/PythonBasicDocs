# %% [markdown]
# ## To check if you have python installed on a Linux or Mac, then on linux open the command line or on Mac open the Terminal and type:

# %% [markdown]
# python --version

# %% [markdown]
# # First Python Program

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Comments starts with a #, and Python will ignore them:

# %%
print("Hello, World!") # hi welcome to python class
# Out:
# Hello, World!

# %%
print("Hello, World!")
# hi welcome to python class
# Out:
# Hello, World!

# %%
#print("Hello, World!")
print("Cheers, Mate!")
# Out:
# Cheers, Mate!

# %% [markdown]
# # Multi Line Comments

# %%
#This is a comment
#written in
#more than just one line
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # or

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # We have 3 type of things in python :
# 1. int
# 2. float
# 3. str

# %%
# int :
1
# Out:
# 1

# %%
# float : 
3.14
# Out:
# 3.14

# %%
# str : 
# we using str for just showing sth not for computing
# any writing thing(even numbers) in the screen is string(str)
# In Python we can use singular quotation or double quotation :::
'Python'
# Out:
# 'Python'

# %%
"Python"
# Out:
# 'Python'

# %% [markdown]
# # for declaring the type of something in PYTHON we should use type:

# %%
type(12)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type("python")
# Out:
# str

# %% [markdown]
# # In other programming languages like C, C++, and Java, you will need to declare the type of variables but in Python you don’t need to do that. Just type in the variable and when values will be given to it, then it will automatically know whether the value given would be an int, float, or char or even a String.
#
# Variables are containers for storing data values.![20140709_python_bytes_3.1.png](attachment:20140709_python_bytes_3.1.png)

# %%
alex = 7
print(alex)
# Out:
# 7

# %%
jack = 101
print(jack)
# Out:
# 101

# %%
john ="a number"
print(john)
# Out:
# a number

# %% [markdown]
# # The Rules
# Variables names must start with a letter or an underscore, such as:
#
# 1. _underscore
# 2. underscore_
#
# The remainder of your variable name may consist of letters, numbers and underscores :
#
# 1. password1
# 2. n00b
# 3. underscores
#
# Names are case sensitive :
#
# 1. casesensitive, CASESENSITIVE, and Case_Sensitive are each a different variable.
#
#
# # Legal variable names:
# 1. myvar = "John"
# 2. my_var = "John"
# 3. _my_var = "John"
# 4. myVar = "John"
# 5. MYVAR = "John"
# 5. myvar2 = "John"
#
# # Illegal variable names:
# 1. 2myvar = "John"
# 2. my-var = "John"
# 3. my var = "John"

# %% [markdown]
# # Assign Value to Multiple Variables:

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# # Output Variables
# The Python print statement is often used to output variables.
#
# To combine both text and a variable, Python uses the + character:

# %%
x = "awesome"
print("Python is " + x)
# Out:
# Python is awesome

# %%
x = "Python is "
y = "awesome"
z =  x + y
print(z)
# Out:
# Python is awesome

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = "5"
y = "10"
print(x + y)
# Out:
# 510

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-00c66e4310ff> in <module>
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # The global Keyword
#
# telling it later

# %% [markdown]
# # Python Variable Assignment and Memory Location:

# %%
peanut_butter = 5
id(peanut_butter)
# Out:
# 140717425140240

# %%
print(id(peanut_butter))
# Out:
# 140717425140240

# %%
crunchy = 5
id(crunchy)
# Out:
# 140717425140240

# %%
crunchy = 7
peanut_butter = crunchy
print(crunchy)
print(peanut_butter)
# Out:
# 7
# 7

# %%
pb = 5

# %%
j = 3

# %%
pb + j
# Out:
# 8

# %%
pbj = pb + j
pbj
# Out:
# 8

# %%
pb = pb - 2
pb
# Out:
# 3

# %%
j = j - 1
j
# Out:
# 2

# %%
pbj = pb + j
pbj
# Out:
# 5

# %%
a = 1
b = 2
c = a * b
print(c)
# Out:
# 2

# %%
print(2 ** 3)
# Out:
# 8

# %%
print(a ** b)
# Out:
# 1

# %%
x = 10
y = x * (1+2)
print(y)
# Out:
# 30

# %%
a = 314 
b = a % 2
print(b)
# Out:
# 0

# %%
b = 'hello'
print(b*2)
# Out:
# hellohello

# %% [markdown]
# # more on numbers:
# There are three numeric types in Python:
#
# 1. int
# 2. float
# 3. complex

# %%
# int
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
# float
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
# complex
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# # Python Casting
# 1. int()
# 2. float()
# 3. str()

# %%
x = int(1)   
y = int(2.8)
z = int("3")

# %%
x = float(1)     
y = float(2.8)  
z = float("3")   
w = float("4.2")

# %%
x = str("s1")
y = str(2)    
z = str(3.0)

# %% [markdown]
# # references :

# %% [markdown]
# 1. [https://www.w3schools.com/python/](https://www.w3schools.com/python/)
# 2. [https://thehelloworldprogram.com/python/python-variable-assignment-statements-rules-conventions-naming/](https://thehelloworldprogram.com/python/python-variable-assignment-statements-rules-conventions-naming/)
# 3. [https://thehelloworldprogram.com/python/python-variable-assignment-memory-location/](https://thehelloworldprogram.com/python/python-variable-assignment-memory-location/)
